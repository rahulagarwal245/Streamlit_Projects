# %%
import streamlit as st

# %%
st.title ("Machine Learning Project")
# Out:
# 2025-09-12 09:56:56.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:56:56.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:56:56.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("Regression model tutorial")
st.subheader("Definition of regression model")
st.text("hello shhdj")
st.markdown("ABCDE")
# Out:
# 2025-09-12 09:58:21.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:58:21.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:58:21.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:58:21.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:58:21.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:58:21.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-12 09:58:21.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
